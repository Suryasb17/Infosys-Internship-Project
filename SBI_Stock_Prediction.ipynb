# %% [markdown]
# <a href="https://colab.research.google.com/github/Suryasb17/Infosys-Internship-Project/blob/main/SBI_Stock_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the data
file_path = '/content/SBIN.csv'
df = pd.read_csv(file_path)

# Convert 'timestamp' to datetime format
df['Date'] = pd.to_datetime(df['Date'])

# Sort the data by date
df = df.sort_values('Date')

# Set the 'timestamp' column as the index
df.set_index('Date', inplace=True)

# Plotting
plt.figure(figsize=(14, 7))
plt.plot(df.index, df['Close'], label='Adj Close', color='blue')
plt.xlabel('Date')
plt.ylabel('Adjusted Close Price (USD)')
plt.title('SBI Monthly Adjusted Close Price')
plt.legend()
plt.grid(True)
plt.show()

# %%
#Histogram:
# Plotting
fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(14, 20))

# Flatten the axes array for easy iteration
axes = axes.flatten()

# Titles for each subplot
columns = ['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
titles = ['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
for ax, column, title in zip(axes, columns, titles):
    ax.hist(df[column].dropna(), bins=30, color='blue', edgecolor='black')
    ax.set_title(title)
    ax.set_ylabel('Frequency')
    ax.set_xlabel(column)

plt.tight_layout()
plt.show()

# Plotting
fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(14, 20), sharex=True)

# Flatten the axes array for easy iteration
axes = axes.flatten()
# Titles for each subplot
columns = ['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
titles = ['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']

for ax, column, title in zip(axes, columns, titles):
    ax.plot(df.index, df[column], label=title, color='blue')
    ax.set_title(title)
    ax.set_ylabel(column)
    ax.legend()
    ax.grid(True)

plt.tight_layout()
plt.show()

# %%
# Load the data
file_path = '/content/SBIN.csv'
df = pd.read_csv(file_path)
# Convert 'date' to datetime format
df['Date'] = pd.to_datetime(df['Date'])

# Sort the data by date
df = df.sort_values('Date')

# Set the 'date' column as the index
df.set_index('Date', inplace=True)

# Extract year and month
df['year'] = df.index.year
df['month'] = df.index.month

# Aggregate the data to get the average close price for each year and month
heatmap_data = df.pivot_table(values='Close', index='year', columns='month', aggfunc='mean')

# Plotting the heatmap
plt.figure(figsize=(14, 7))
sns.heatmap(heatmap_data, cmap='YlGnBu', annot=True, fmt=".2f", linewidths=.5)
plt.xlabel('Month')
plt.ylabel('Year')
plt.title('Average Monthly Close Price Heatmap')
plt.show()

# %%
#cleaning the data
def load_and_clean_data(file_path):
    df = pd.read_csv(file_path)
    df['date'] = pd.to_datetime(df['date'])
    df = df.sort_values('date')
    df.set_index('date', inplace=True)
    return df.dropna()

# %%
from sklearn.preprocessing import MinMaxScaler

def normalize_data(df):
    data = df.filter(['Close'])
    scaler = MinMaxScaler(feature_range=(0, 1))
    scaled_data = scaler.fit_transform(data)
    return scaled_data, scaler

# Normalize the data
scaled_data, scaler = normalize_data(df)

# %%
def split_data(scaled_data, train_size=0.7, val_size=0.15):
    train_len = int(len(scaled_data) * train_size)
    val_len = int(len(scaled_data) * val_size)
    train_data = scaled_data[:train_len]
    val_data = scaled_data[train_len:train_len + val_len]
    test_data = scaled_data[train_len + val_len:]
    return train_data, val_data, test_data

# Split the data
train_data, val_data, test_data = split_data(scaled_data)

# %%
import numpy as np
def prepare_data(data, time_step=60):
    x, y = [], []
    for i in range(time_step, len(data)):
        x.append(data[i-time_step:i, 0])
        y.append(data[i, 0])
    x, y = np.array(x), np.array(y)
    x = np.reshape(x, (x.shape[0], x.shape[1], 1))
    return x, y

# Prepare training data
x_train, y_train = prepare_data(train_data)

# Prepare validation data
x_val, y_val = prepare_data(val_data)

# %%
# Plotting the data after splitting
plt.figure(figsize=(14, 7))

# Plot training data
plt.plot(df.index[:len(train_data)], train_data, label='Train', color='blue')

# Plot validation data
plt.plot(df.index[len(train_data):len(train_data) + len(val_data)], val_data, label='Validation', color='green')

# Plot test data
plt.plot(df.index[len(train_data) + len(val_data):], test_data, label='Test', color='red')

plt.xlabel('Date')
plt.ylabel('Adjusted Close Price (USD)')
plt.title('Adjusted Close Price after Data Splitting')
plt.legend()
plt.grid(True)
plt.show()

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam

def build_stacked_lstm_model(input_shape):
    model = Sequential()
    model.add(LSTM(units=100, return_sequences=True, input_shape=input_shape))
    model.add(Dropout(0.5))
    model.add(LSTM(units=100, return_sequences=True))
    model.add(Dropout(0.5))
    model.add(LSTM(units=100))
    model.add(Dropout(0.5))
    model.add(Dense(units=1))
    optimizer = Adam(learning_rate=0.0001)
    model.compile(optimizer=optimizer, loss='mean_squared_error')
    return model

# Build the model
model = build_stacked_lstm_model((x_train.shape[1], 1))

# %%
# Train the model
model.fit(x_train, y_train, epochs=200, batch_size=64, validation_data=(x_val, y_val), verbose=1)
# Out:
# Epoch 1/200
# 11/11 [==============================] - 11s 395ms/step - loss: 0.2462 - val_loss: 0.4021
# Epoch 2/200
# 11/11 [==============================] - 5s 441ms/step - loss: 0.1152 - val_loss: 0.1192
# Epoch 3/200
# 11/11 [==============================] - 4s 319ms/step - loss: 0.0242 - val_loss: 0.0062
# Epoch 4/200
# 11/11 [==============================] - 3s 272ms/step - loss: 0.0215 - val_loss: 0.0248
# Epoch 5/200
# 11/11 [==============================] - 3s 268ms/step - loss: 0.0156 - val_loss: 0.0299
# Epoch 6/200
# 11/11 [==============================] - 4s 365ms/step - loss: 0.0140 - val_loss: 0.0130
# Epoch 7/200
# 11/11 [==============================] - 5s 418ms/step - loss: 0.0142 - val_loss: 0.0158
# Epoch 8/200
# 11/11 [==============================] - 3s 268ms/step - loss: 0.0140 - val_loss: 0.0152
# Epoch 9/200
# 11/11 [==============================] - 3s 260ms/step - loss: 0.0134 - val_loss: 0.0163
# Epoch 10/200
# 11/11 [==============================] - 3s 273ms/step - loss: 0.0122 - val_loss: 0.0147
# Epoch 11/200
# 11/11 [==============================] - 5s 483ms/step - loss: 0.0129 - val_loss: 0.0169
# Epoch 12/200
# 11/11 [==============================] - 3s 273ms/step - loss: 0.0133 - val_loss: 0.0208
# Epoch 13/200
# 11/11 [==============================] - 3s 267ms/step - loss: 0.0123 - val_loss: 0.0131
# Epoch 14/200
# 11/11 [==============================] - 3s 270ms/step - loss: 0.0114 - val_loss: 0.0173
# Epoch 15/200
# 11/11 [==============================] - 5s 481ms/step - loss: 0.0117 - val_loss: 0.0130
# Epoch 16/200
# 11/11 [==============================] - 3s 270ms/step - loss: 0.0116 - val_loss: 0.0159
# Epoch 17/200
# 11/11 [==============================] - 3s 267ms/step - loss: 0.0116 - val_loss: 0.0141
# Epoch 18/200
# 11/11 [==============================] - 3s 271ms/step - loss: 0.0111 - val_loss: 0.0168
# Epoch 19/200
# 11/11 [==============================] - 4s 418ms/step - loss: 0.0111 - val_loss: 0.0127
# Epoch 20/200
# 11/11 [==============================] - 4s 357ms/step - loss: 0.0117 - val_loss: 0.0143
# Epoch 21/200
# 11/11 [==============================] - 3s 260ms/step - loss: 0.0105 - val_loss: 0.0104
# Epoch 22/200
# 11/11 [==============================] - 3s 264ms/step - loss: 0.0093 - val_loss: 0.0164
# Epoch 23/200
# 11/11 [==============================] - 3s 290ms/step - loss: 0.0110 - val_loss: 0.0132
# Epoch 24/200
# 11/11 [==============================] - 5s 468ms/step - loss: 0.0101 - val_loss: 0.0136
# Epoch 25/200
# 11/11 [==============================] - 3s 262ms/step - loss: 0.0105 - val_loss: 0.0131
# Epoch 26/200
# 11/11 [==============================] - 3s 264ms/step - loss: 0.0109 - val_loss: 0.0131
# Epoch 27/200
# 11/11 [==============================] - 3s 268ms/step - loss: 0.0108 - val_loss: 0.0118
# Epoch 28/200
# 11/11 [==============================] - 6s 538ms/step - loss: 0.0099 - val_loss: 0.0140
# Epoch 29/200
# 11/11 [==============================] - 3s 275ms/step - loss: 0.0097 - val_loss: 0.0103
# Epoch 30/200
# 11/11 [==============================] - 3s 259ms/step - loss: 0.0116 - val_loss: 0.0171
# Epoch 31/200
# 11/11 [==============================] - 3s 273ms/step - loss: 0.0103 - val_loss: 0.0105
# Epoch 32/200
# 11/11 [==============================] - 4s 386ms/step - loss: 0.0092 - val_loss: 0.0125
# Epoch 33/200
# 11/11 [==============================] - 5s 398ms/step - loss: 0.0102 - val_loss: 0.0126
# Epoch 34/200
# 11/11 [==============================] - 3s 266ms/step - loss: 0.0098 - val_loss: 0.0106
# Epoch 35/200
# 11/11 [==============================] - 3s 269ms/step - loss: 0.0094 - val_loss: 0.0130
# Epoch 36/200
# 11/11 [==============================] - 3s 286ms/step - loss: 0.0103 - val_loss: 0.0114
# Epoch 37/200
# 11/11 [==============================] - 5s 480ms/step - loss: 0.0093 - val_loss: 0.0121
# Epoch 38/200
# 11/11 [==============================] - 3s 263ms/step - loss: 0.0084 - val_loss: 0.0120
# Epoch 39/200
# 11/11 [==============================] - 3s 263ms/step - loss: 0.0097 - val_loss: 0.0120
# Epoch 40/200
# 11/11 [==============================] - 3s 267ms/step - loss: 0.0095 - val_loss: 0.0148
# Epoch 41/200
# 11/11 [==============================] - 5s 435ms/step - loss: 0.0099 - val_loss: 0.0092
# Epoch 42/200
# 11/11 [==============================] - 6s 524ms/step - loss: 0.0096 - val_loss: 0.0150
# Epoch 43/200
# 11/11 [==============================] - 3s 293ms/step - loss: 0.0096 - val_loss: 0.0087
# Epoch 44/200
# 11/11 [==============================] - 3s 299ms/step - loss: 0.0090 - val_loss: 0.0153
# Epoch 45/200
# 11/11 [==============================] - 5s 480ms/step - loss: 0.0095 - val_loss: 0.0128
# Epoch 46/200
# 11/11 [==============================] - 3s 258ms/step - loss: 0.0091 - val_loss: 0.0117
# Epoch 47/200
# 11/11 [==============================] - 3s 261ms/step - loss: 0.0087 - val_loss: 0.0112
# Epoch 48/200
# 11/11 [==============================] - 3s 263ms/step - loss: 0.0090 - val_loss: 0.0122
# Epoch 49/200
# 11/11 [==============================] - 5s 441ms/step - loss: 0.0087 - val_loss: 0.0089
# Epoch 50/200
# 11/11 [==============================] - 4s 326ms/step - loss: 0.0099 - val_loss: 0.0115
# Epoch 51/200
# 11/11 [==============================] - 3s 269ms/step - loss: 0.0084 - val_loss: 0.0135
# Epoch 52/200
# 11/11 [==============================] - 3s 268ms/step - loss: 0.0089 - val_loss: 0.0111
# Epoch 53/200
# 11/11 [==============================] - 4s 346ms/step - loss: 0.0084 - val_loss: 0.0130
# Epoch 54/200
# 11/11 [==============================] - 4s 394ms/step - loss: 0.0089 - val_loss: 0.0104
# Epoch 55/200
# 11/11 [==============================] - 3s 268ms/step - loss: 0.0083 - val_loss: 0.0105
# Epoch 56/200
# 11/11 [==============================] - 3s 260ms/step - loss: 0.0094 - val_loss: 0.0134
# Epoch 57/200
# 11/11 [==============================] - 3s 264ms/step - loss: 0.0080 - val_loss: 0.0094
# Epoch 58/200
# 11/11 [==============================] - 6s 512ms/step - loss: 0.0081 - val_loss: 0.0117
# Epoch 59/200
# 11/11 [==============================] - 3s 261ms/step - loss: 0.0081 - val_loss: 0.0133
# Epoch 60/200
# 11/11 [==============================] - 3s 267ms/step - loss: 0.0091 - val_loss: 0.0088
# Epoch 61/200
# 11/11 [==============================] - 3s 262ms/step - loss: 0.0082 - val_loss: 0.0108
# Epoch 62/200
# 11/11 [==============================] - 4s 405ms/step - loss: 0.0086 - val_loss: 0.0121
# Epoch 63/200
# 11/11 [==============================] - 4s 365ms/step - loss: 0.0087 - val_loss: 0.0133
# Epoch 64/200
# 11/11 [==============================] - 3s 261ms/step - loss: 0.0088 - val_loss: 0.0087
# Epoch 65/200
# 11/11 [==============================] - 3s 258ms/step - loss: 0.0092 - val_loss: 0.0083
# Epoch 66/200
# 11/11 [==============================] - 3s 296ms/step - loss: 0.0083 - val_loss: 0.0130
# Epoch 67/200
# 11/11 [==============================] - 5s 461ms/step - loss: 0.0081 - val_loss: 0.0109
# Epoch 68/200
# 11/11 [==============================] - 3s 270ms/step - loss: 0.0085 - val_loss: 0.0087
# Epoch 69/200
# 11/11 [==============================] - 3s 273ms/step - loss: 0.0079 - val_loss: 0.0142
# Epoch 70/200
# 11/11 [==============================] - 3s 268ms/step - loss: 0.0078 - val_loss: 0.0103
# Epoch 71/200
# 11/11 [==============================] - 5s 481ms/step - loss: 0.0086 - val_loss: 0.0074
# Epoch 72/200
# 11/11 [==============================] - 3s 269ms/step - loss: 0.0087 - val_loss: 0.0191
# Epoch 73/200
# 11/11 [==============================] - 3s 267ms/step - loss: 0.0078 - val_loss: 0.0080
# Epoch 74/200
# 11/11 [==============================] - 3s 267ms/step - loss: 0.0079 - val_loss: 0.0120
# Epoch 75/200
# 11/11 [==============================] - 4s 394ms/step - loss: 0.0085 - val_loss: 0.0147
# Epoch 76/200
# 11/11 [==============================] - 4s 348ms/step - loss: 0.0075 - val_loss: 0.0060
# Epoch 77/200
# 11/11 [==============================] - 3s 275ms/step - loss: 0.0078 - val_loss: 0.0120
# Epoch 78/200
# 11/11 [==============================] - 3s 304ms/step - loss: 0.0076 - val_loss: 0.0082
# Epoch 79/200
# 11/11 [==============================] - 4s 378ms/step - loss: 0.0081 - val_loss: 0.0085
# Epoch 80/200
# 11/11 [==============================] - 5s 403ms/step - loss: 0.0077 - val_loss: 0.0119
# Epoch 81/200
# 11/11 [==============================] - 3s 269ms/step - loss: 0.0074 - val_loss: 0.0076
# Epoch 82/200
# 11/11 [==============================] - 3s 269ms/step - loss: 0.0075 - val_loss: 0.0127
# Epoch 83/200
# 11/11 [==============================] - 3s 296ms/step - loss: 0.0080 - val_loss: 0.0083
# Epoch 84/200
# 11/11 [==============================] - 5s 489ms/step - loss: 0.0076 - val_loss: 0.0091
# Epoch 85/200
# 11/11 [==============================] - 3s 277ms/step - loss: 0.0078 - val_loss: 0.0084
# Epoch 86/200
# 11/11 [==============================] - 3s 266ms/step - loss: 0.0071 - val_loss: 0.0103
# Epoch 87/200
# 11/11 [==============================] - 3s 268ms/step - loss: 0.0079 - val_loss: 0.0084
# Epoch 88/200
# 11/11 [==============================] - 5s 458ms/step - loss: 0.0075 - val_loss: 0.0088
# Epoch 89/200
# 11/11 [==============================] - 3s 289ms/step - loss: 0.0076 - val_loss: 0.0091
# Epoch 90/200
# 11/11 [==============================] - 3s 268ms/step - loss: 0.0071 - val_loss: 0.0103
# Epoch 91/200
# 11/11 [==============================] - 3s 267ms/step - loss: 0.0072 - val_loss: 0.0072
# Epoch 92/200
# 11/11 [==============================] - 4s 389ms/step - loss: 0.0076 - val_loss: 0.0093
# Epoch 93/200
# 11/11 [==============================] - 6s 542ms/step - loss: 0.0072 - val_loss: 0.0091
# Epoch 94/200
# 11/11 [==============================] - 4s 319ms/step - loss: 0.0069 - val_loss: 0.0096
# Epoch 95/200
# 11/11 [==============================] - 3s 273ms/step - loss: 0.0065 - val_loss: 0.0073
# Epoch 96/200
# 11/11 [==============================] - 3s 266ms/step - loss: 0.0066 - val_loss: 0.0078
# Epoch 97/200
# 11/11 [==============================] - 5s 505ms/step - loss: 0.0074 - val_loss: 0.0097
# Epoch 98/200
# 11/11 [==============================] - 3s 269ms/step - loss: 0.0073 - val_loss: 0.0128
# Epoch 99/200
# 11/11 [==============================] - 3s 262ms/step - loss: 0.0074 - val_loss: 0.0084
# Epoch 100/200
# 11/11 [==============================] - 3s 267ms/step - loss: 0.0067 - val_loss: 0.0100
# Epoch 101/200
# 11/11 [==============================] - 4s 385ms/step - loss: 0.0069 - val_loss: 0.0088
# Epoch 102/200
# 11/11 [==============================] - 4s 392ms/step - loss: 0.0071 - val_loss: 0.0111
# Epoch 103/200
# 11/11 [==============================] - 3s 269ms/step - loss: 0.0075 - val_loss: 0.0137
# Epoch 104/200
# 11/11 [==============================] - 3s 268ms/step - loss: 0.0077 - val_loss: 0.0074
# Epoch 105/200
# 11/11 [==============================] - 3s 285ms/step - loss: 0.0073 - val_loss: 0.0102
# Epoch 106/200
# 11/11 [==============================] - 5s 476ms/step - loss: 0.0063 - val_loss: 0.0098
# Epoch 107/200
# 11/11 [==============================] - 3s 267ms/step - loss: 0.0069 - val_loss: 0.0101
# Epoch 108/200
# 11/11 [==============================] - 3s 266ms/step - loss: 0.0062 - val_loss: 0.0075
# Epoch 109/200
# 11/11 [==============================] - 3s 271ms/step - loss: 0.0069 - val_loss: 0.0115
# Epoch 110/200
# 11/11 [==============================] - 5s 477ms/step - loss: 0.0065 - val_loss: 0.0065
# Epoch 111/200
# 11/11 [==============================] - 3s 289ms/step - loss: 0.0069 - val_loss: 0.0079
# Epoch 112/200
# 11/11 [==============================] - 3s 277ms/step - loss: 0.0074 - val_loss: 0.0133
# Epoch 113/200
# 11/11 [==============================] - 3s 268ms/step - loss: 0.0069 - val_loss: 0.0085
# Epoch 114/200
# 11/11 [==============================] - 4s 405ms/step - loss: 0.0071 - val_loss: 0.0100
# Epoch 115/200
# 11/11 [==============================] - 4s 368ms/step - loss: 0.0067 - val_loss: 0.0122
# Epoch 116/200
# 11/11 [==============================] - 3s 277ms/step - loss: 0.0075 - val_loss: 0.0067
# Epoch 117/200
# 11/11 [==============================] - 3s 273ms/step - loss: 0.0068 - val_loss: 0.0113
# Epoch 118/200
# 11/11 [==============================] - 3s 313ms/step - loss: 0.0065 - val_loss: 0.0055
# Epoch 119/200
# 11/11 [==============================] - 5s 467ms/step - loss: 0.0076 - val_loss: 0.0082
# Epoch 120/200
# 11/11 [==============================] - 3s 270ms/step - loss: 0.0064 - val_loss: 0.0097
# Epoch 121/200
# 11/11 [==============================] - 3s 271ms/step - loss: 0.0070 - val_loss: 0.0065
# Epoch 122/200
# 11/11 [==============================] - 3s 265ms/step - loss: 0.0073 - val_loss: 0.0099
# Epoch 123/200
# 11/11 [==============================] - 5s 472ms/step - loss: 0.0064 - val_loss: 0.0109
# Epoch 124/200
# 11/11 [==============================] - 3s 262ms/step - loss: 0.0065 - val_loss: 0.0094
# Epoch 125/200
# 11/11 [==============================] - 3s 267ms/step - loss: 0.0065 - val_loss: 0.0064
# Epoch 126/200
# 11/11 [==============================] - 3s 265ms/step - loss: 0.0068 - val_loss: 0.0076
# Epoch 127/200
# 11/11 [==============================] - 4s 377ms/step - loss: 0.0065 - val_loss: 0.0120
# Epoch 128/200
# 11/11 [==============================] - 4s 392ms/step - loss: 0.0064 - val_loss: 0.0123
# Epoch 129/200
# 11/11 [==============================] - 3s 267ms/step - loss: 0.0061 - val_loss: 0.0088
# Epoch 130/200
# 11/11 [==============================] - 3s 266ms/step - loss: 0.0066 - val_loss: 0.0081
# Epoch 131/200
# 11/11 [==============================] - 3s 287ms/step - loss: 0.0066 - val_loss: 0.0049
# Epoch 132/200
# 11/11 [==============================] - 5s 487ms/step - loss: 0.0081 - val_loss: 0.0109
# Epoch 133/200
# 11/11 [==============================] - 3s 267ms/step - loss: 0.0068 - val_loss: 0.0128
# Epoch 134/200
# 11/11 [==============================] - 3s 263ms/step - loss: 0.0068 - val_loss: 0.0136
# Epoch 135/200
# 11/11 [==============================] - 3s 262ms/step - loss: 0.0067 - val_loss: 0.0051
# Epoch 136/200
# 11/11 [==============================] - 5s 448ms/step - loss: 0.0071 - val_loss: 0.0076
# Epoch 137/200
# 11/11 [==============================] - 4s 335ms/step - loss: 0.0064 - val_loss: 0.0150
# Epoch 138/200
# 11/11 [==============================] - 3s 262ms/step - loss: 0.0063 - val_loss: 0.0072
# Epoch 139/200
# 11/11 [==============================] - 3s 265ms/step - loss: 0.0066 - val_loss: 0.0071
# Epoch 140/200
# 11/11 [==============================] - 4s 327ms/step - loss: 0.0063 - val_loss: 0.0098
# Epoch 141/200
# 11/11 [==============================] - 5s 443ms/step - loss: 0.0061 - val_loss: 0.0069
# Epoch 142/200
# 11/11 [==============================] - 3s 263ms/step - loss: 0.0064 - val_loss: 0.0088
# Epoch 143/200
# 11/11 [==============================] - 4s 358ms/step - loss: 0.0059 - val_loss: 0.0097
# Epoch 144/200
# 11/11 [==============================] - 6s 533ms/step - loss: 0.0067 - val_loss: 0.0078
# Epoch 145/200
# 11/11 [==============================] - 4s 367ms/step - loss: 0.0060 - val_loss: 0.0101
# Epoch 146/200
# 11/11 [==============================] - 3s 268ms/step - loss: 0.0058 - val_loss: 0.0092
# Epoch 147/200
# 11/11 [==============================] - 3s 266ms/step - loss: 0.0059 - val_loss: 0.0101
# Epoch 148/200
# 11/11 [==============================] - 3s 312ms/step - loss: 0.0057 - val_loss: 0.0081
# Epoch 149/200
# 11/11 [==============================] - 5s 470ms/step - loss: 0.0066 - val_loss: 0.0107
# Epoch 150/200
# 11/11 [==============================] - 3s 268ms/step - loss: 0.0072 - val_loss: 0.0119
# Epoch 151/200
# 11/11 [==============================] - 3s 263ms/step - loss: 0.0060 - val_loss: 0.0068
# Epoch 152/200
# 11/11 [==============================] - 3s 264ms/step - loss: 0.0062 - val_loss: 0.0056
# Epoch 153/200
# 11/11 [==============================] - 5s 490ms/step - loss: 0.0064 - val_loss: 0.0089
# Epoch 154/200
# 11/11 [==============================] - 3s 282ms/step - loss: 0.0064 - val_loss: 0.0097
# Epoch 155/200
# 11/11 [==============================] - 3s 262ms/step - loss: 0.0062 - val_loss: 0.0079
# Epoch 156/200
# 11/11 [==============================] - 3s 267ms/step - loss: 0.0065 - val_loss: 0.0116
# Epoch 157/200
# 11/11 [==============================] - 4s 374ms/step - loss: 0.0063 - val_loss: 0.0095
# Epoch 158/200
# 11/11 [==============================] - 4s 392ms/step - loss: 0.0057 - val_loss: 0.0067
# Epoch 159/200
# 11/11 [==============================] - 3s 257ms/step - loss: 0.0068 - val_loss: 0.0083
# Epoch 160/200
# 11/11 [==============================] - 3s 257ms/step - loss: 0.0063 - val_loss: 0.0092
# Epoch 161/200
# 11/11 [==============================] - 3s 269ms/step - loss: 0.0059 - val_loss: 0.0112
# Epoch 162/200
# 11/11 [==============================] - 5s 509ms/step - loss: 0.0061 - val_loss: 0.0064
# Epoch 163/200
# 11/11 [==============================] - 3s 257ms/step - loss: 0.0062 - val_loss: 0.0099
# Epoch 164/200
# 11/11 [==============================] - 3s 263ms/step - loss: 0.0066 - val_loss: 0.0057
# Epoch 165/200
# 11/11 [==============================] - 3s 267ms/step - loss: 0.0065 - val_loss: 0.0123
# Epoch 166/200
# 11/11 [==============================] - 4s 396ms/step - loss: 0.0064 - val_loss: 0.0073
# Epoch 167/200
# 11/11 [==============================] - 4s 346ms/step - loss: 0.0061 - val_loss: 0.0100
# Epoch 168/200
# 11/11 [==============================] - 3s 265ms/step - loss: 0.0062 - val_loss: 0.0110
# Epoch 169/200
# 11/11 [==============================] - 3s 265ms/step - loss: 0.0061 - val_loss: 0.0068
# Epoch 170/200
# 11/11 [==============================] - 3s 312ms/step - loss: 0.0063 - val_loss: 0.0087
# Epoch 171/200
# 11/11 [==============================] - 5s 466ms/step - loss: 0.0056 - val_loss: 0.0076
# Epoch 172/200
# 11/11 [==============================] - 3s 262ms/step - loss: 0.0062 - val_loss: 0.0075
# Epoch 173/200
# 11/11 [==============================] - 3s 266ms/step - loss: 0.0060 - val_loss: 0.0056
# Epoch 174/200
# 11/11 [==============================] - 3s 263ms/step - loss: 0.0058 - val_loss: 0.0131
# Epoch 175/200
# 11/11 [==============================] - 5s 473ms/step - loss: 0.0072 - val_loss: 0.0096
# Epoch 176/200
# 11/11 [==============================] - 3s 267ms/step - loss: 0.0064 - val_loss: 0.0080
# Epoch 177/200
# 11/11 [==============================] - 3s 267ms/step - loss: 0.0058 - val_loss: 0.0073
# Epoch 178/200
# 11/11 [==============================] - 3s 267ms/step - loss: 0.0058 - val_loss: 0.0078
# Epoch 179/200
# 11/11 [==============================] - 4s 394ms/step - loss: 0.0060 - val_loss: 0.0084
# Epoch 180/200
# 11/11 [==============================] - 4s 372ms/step - loss: 0.0063 - val_loss: 0.0067
# Epoch 181/200
# 11/11 [==============================] - 3s 270ms/step - loss: 0.0056 - val_loss: 0.0081
# Epoch 182/200
# 11/11 [==============================] - 3s 272ms/step - loss: 0.0059 - val_loss: 0.0122
# Epoch 183/200
# 11/11 [==============================] - 3s 314ms/step - loss: 0.0060 - val_loss: 0.0084
# Epoch 184/200
# 11/11 [==============================] - 5s 463ms/step - loss: 0.0051 - val_loss: 0.0065
# Epoch 185/200
# 11/11 [==============================] - 3s 264ms/step - loss: 0.0064 - val_loss: 0.0094
# Epoch 186/200
# 11/11 [==============================] - 3s 267ms/step - loss: 0.0057 - val_loss: 0.0090
# Epoch 187/200
# 11/11 [==============================] - 3s 273ms/step - loss: 0.0056 - val_loss: 0.0054
# Epoch 188/200
# 11/11 [==============================] - 5s 488ms/step - loss: 0.0059 - val_loss: 0.0059
# Epoch 189/200
# 11/11 [==============================] - 3s 265ms/step - loss: 0.0058 - val_loss: 0.0102
# Epoch 190/200
# 11/11 [==============================] - 3s 270ms/step - loss: 0.0059 - val_loss: 0.0083
# Epoch 191/200
# 11/11 [==============================] - 3s 265ms/step - loss: 0.0054 - val_loss: 0.0081
# Epoch 192/200
# 11/11 [==============================] - 4s 392ms/step - loss: 0.0051 - val_loss: 0.0067
# Epoch 193/200
# 11/11 [==============================] - 4s 382ms/step - loss: 0.0057 - val_loss: 0.0072
# Epoch 194/200
# 11/11 [==============================] - 6s 514ms/step - loss: 0.0061 - val_loss: 0.0117
# Epoch 195/200
# 11/11 [==============================] - 3s 287ms/step - loss: 0.0061 - val_loss: 0.0080
# Epoch 196/200
# 11/11 [==============================] - 5s 485ms/step - loss: 0.0062 - val_loss: 0.0055
# Epoch 197/200
# 11/11 [==============================] - 3s 261ms/step - loss: 0.0060 - val_loss: 0.0084
# Epoch 198/200
# 11/11 [==============================] - 3s 265ms/step - loss: 0.0058 - val_loss: 0.0119
# Epoch 199/200
# 11/11 [==============================] - 3s 266ms/step - loss: 0.0053 - val_loss: 0.0107
# Epoch 200/200
# 11/11 [==============================] - 5s 438ms/step - loss: 0.0054 - val_loss: 0.0058

# %%
# Make predictions on training data
train_predictions = model.predict(x_train)

# Prepare testing data and corresponding actual values
x_test, y_test_actual = prepare_data(test_data)

# Make predictions on test data
test_predictions = model.predict(x_test)


# Plotting training predictions against actual training observations
plt.figure(figsize=(14, 7))
plt.plot(df.index[60:60+len(y_train)], y_train, label='Actual Training Observations', color='blue')
plt.plot(df.index[60:60+len(train_predictions)], train_predictions, label='Training Predictions', color='orange')
plt.xlabel('Date')
plt.ylabel('Adjusted Close Price (Scaled)')
plt.title('Training Predictions vs Actual Training Observations')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# 21/21 [==============================] - 3s 66ms/step
# 3/3 [==============================] - 0s 47ms/step

# %%
from sklearn.metrics import mean_squared_error
# Make predictions on training data

train_predictions = model.predict(x_train)

# Prepare testing data and corresponding actual values
def prepare_testing_data(test_data, time_step=60):
    x_test = []
    for i in range(time_step, len(test_data)):
        x_test.append(test_data[i-time_step:i, 0])
    x_test = np.array(x_test)
    x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))
    return x_test, test_data[time_step:]

# Prepare testing data and corresponding actual values
x_test, y_test_actual = prepare_testing_data(test_data)

# Make predictions on test data
test_predictions = model.predict(x_test)

def calculate_metrics(y_true, y_pred):
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    mse = mean_squared_error(y_true, y_pred)
    return rmse, mse

    # Calculate RMSE and MSE for training data
train_rmse, train_mse = calculate_metrics(y_train, train_predictions)
print(f'Training RMSE(Root mean squared error): {train_rmse}')
print(f'Training MSE(Mean squared error): {train_mse}')

# Calculate RMSE and MSE for test data
test_rmse, test_mse = calculate_metrics(y_test_actual, test_predictions)
print(f'Test RMSE(Root mean squared error): {test_rmse}')
print(f'Test MSE(Mean squared error): {test_mse}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-26aef330e131> in <cell line: 4>()
#       2 # Make predictions on training data
#       3
# ----> 4 train_predictions = model.predict(x_train)
#       5
#       6 # Prepare testing data and corresponding actual values
#
# NameError: name 'model' is not defined
